# %%
import spacy
import pandas as pd
import os
from spacy import displacy

# %%
os.chdir('F:\WorkSpacePy\DeepCoNN')
nlp = spacy.load('en_core_web_lg')

# %%
data = pd.read_json('data/music/music_data.json')
print(data.dtypes)
# data.describe()
# Out:
# item             object
# rating            int64
# review_text      object
# reviewTime       object
# user             object
# reviewerName     object
# word_list        object
# un_used_words    object
# dtype: object

# %%
item_sample = data['item'].sample(1).values[0]
data_sample = data[data['item'] == item_sample]
print('item:', item_sample)
print('review size:', len(data_sample))
# Out:
# item: B000WCDI6O
# review size: 45

# %%
review_list = data_sample['review_text'].to_list()
review_sample = review_list[0]
print(review_sample)
# Out:
# Almost every track on this cd has a softer beat over ridiculously spit lyrics.(as usual for Jay).  Just read the below lyrics from the album, you'll understand."Yo Boy's off the wall these other n***** is Tito"&lt;-this one's pretty out there and sophisticated.  "Off the Wall" was a highly successful Michael Jackson album, Tito was the worse member of the Jackson 5.  haha!"and I sport fly s*** I should win an Espy""Move Coke like Pepsi, don't matter what the brand name is.""Stay outta trouble, momma said, as momma sighedHer fear her youngest son be a victim of homicideBut I gotta get you outta here momma, or I'mma die...inside.""We ain't thugs for the sake of bein thugs,nobody do that where we grew at n**** duh!The poverty line we not above,So we come in mask and gloves,cuz we ain't feelin the love.We ain't doin' crime for the sake of doin' crime.We movin' dimes cuz we ain't doin' fine.1 out of 3 of us is locked up doin' time,you know what that type of s*** could do to a n**** mind?m
# ...

# %%
docs = [nlp(text) for text in review_list]
for i, sent in enumerate(docs[0].sents):
    print(str(i), sent)
# Out:
# 0 Almost every track on this cd has a softer beat over ridiculously spit lyrics.(as usual for Jay).
# 1 Just read the below lyrics from the album, you'll understand."Yo
# 2 Boy's off the wall
# 3 these other n
# 4 **
# 5 *
# 6 *
# 7 * is Tito"&lt;-this one's pretty out there and sophisticated.
# 8 "Off the Wall" was a highly successful Michael Jackson album, Tito was the worse member of the Jackson 5.
# 9 haha!"and
# 10 I sport fly
# 11 s
# 12 *
# 13 *
# 14 * I should win an Espy""Move Coke like Pepsi, don't matter what the brand name
# 15 is.""Stay outta trouble, momma said, as momma sighedHer fear her youngest son be a victim of homicideBut
# 16 I gotta get you outta here momma, or I'mma die...
# 17 inside.""We ain't thugs for the sake of bein thugs,nobody do that where we grew at n
# 18 *
# 19 *
# 20 *
# 21 * duh!The poverty line we not above
# 22 ,So we come in mask and gloves,cuz we ain't feelin the love.
# 23 We ain't doin' crime for the sake of doin' crime.
# ...

# %%
# displacy.render(docs, style='ent')
# Out:
# D:\Anaconda3\envs\deep-learning-py36\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# D:\Anaconda3\envs\deep-learning-py36\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# D:\Anaconda3\envs\deep-learning-py36\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# ...
